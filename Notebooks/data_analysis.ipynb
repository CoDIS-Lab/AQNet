# %%
import pandas as pd
import seaborn as sn

# %%
data = pd.read_csv(r'C:/DissertationCode/NO2_Prediction/data/multimodal/samples_multimodal.csv')

# %%
data.head()
# Out:
#    idx AirQualityStation                                           img_path  \
# 0    3       STA-BETR701  STA-BETR701/S2A_MSIL2A_20200530T105031_N0214_R...
# 1   28    STA.DE_DEHB005  STA.DE_DEHB005/S2B_MSIL2A_20201225T103339_N021...
# 2   38       STA-SI0054A  STA-SI0054A/S2A_MSIL2A_20200912T100031_N0214_R...
# 3   42       STA-RO0192A  STA-RO0192A/S2A_MSIL2A_20200828T090601_N0214_R...
# 4   45       STA_ES1353A  STA_ES1353A/S2B_MSIL2A_20200623T112119_N0214_R...
#
#                                             s5p_path Countrycode  Altitude  \
# 0  STA-BETR701/l3_mean_europe_2018_2020_005dg.netcdf          BE         5
# 1  STA.DE_DEHB005/l3_mean_europe_2018_2020_005dg....          DE         3
# 2  STA-SI0054A/l3_mean_europe_2018_2020_005dg.netcdf          SI       250
# 3  STA-RO0192A/l3_mean_europe_2018_2020_005dg.netcdf          RO        31
# 4  STA_ES1353A/l3_mean_europe_2018_2020_005dg.netcdf          ES       216
#
# ...

# %%
#POLLUTANT CORRELATION
pollutant_data = data[["no2","o3","co","so2","pm10"]]
pollutant_data.head()
# Out:
#          no2         o3        co       so2       pm10
# 0  25.748567  43.681846  0.254487  0.897980  29.233349
# 1  19.481098  49.611957  0.173302  2.039645  18.642352
# 2  16.198280  43.789559  0.440238  4.749047  26.876751
# 3  12.511371  57.058327  0.534755  5.599474  21.332493
# 4  17.706891  48.925964  0.415468  7.444815  23.740473

# %%
sn.heatmap(pollutant_data.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>
